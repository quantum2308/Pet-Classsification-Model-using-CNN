# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(32,kernel_size = (5,5),activation='relu',input_shape=(64,64,3)))
model.add(tf.keras.layers.Conv2D(32,kernel_size = (5,5),activation='relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size = (2,2) , strides = 2 ))
model.add(tf.keras.layers.Conv2D(64,kernel_size = (5,5),activation='relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size = (2,2) , strides = 2))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(32, activation = 'relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.4))
model.add(tf.keras.layers.Dense(1,activation='softmax'))
model.compile(optimizer = 'adam',loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 60, 60, 32)        2432
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 56, 56, 32)        25632
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 64)        51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                294944
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_set = train_datagen.flow_from_directory('Downloads\\data\\train' , target_size=(64,64), batch_size=1, class_mode='binary')
# Out:
# Found 40 images belonging to 2 classes.

# %%
test_set = test_datagen.flow_from_directory('Downloads\\data\\test', target_size=(64,64),batch_size= 1,class_mode='binary')
# Out:
# Found 20 images belonging to 2 classes.

# %%
model.fit_generator(train_set,steps_per_epoch=10,epochs=100 , validation_data = test_set)
# Out:
# WARNING:tensorflow:From <ipython-input-10-0efc573a74b9>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 10/10 [==============================] - 1s 72ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 2/100
# 10/10 [==============================] - 0s 28ms/step - loss: 10.6745 - accuracy: 0.3000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 3/100
# 10/10 [==============================] - 0s 31ms/step - loss: 3.0498 - accuracy: 0.8000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 4/100
# 10/10 [==============================] - 0s 36ms/step - loss: 4.5748 - accuracy: 0.7000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 5/100
# 10/10 [==============================] - 0s 31ms/step - loss: 6.0997 - accuracy: 0.6000 - val_loss: 7.6246 - val_accuracy: 0.5000
# ...

# %%
model.fit_generator(train_set,steps_per_epoch=10,epochs=200 , validation_data = test_set)
# Out:
# Epoch 1/200
# 10/10 [==============================] - 0s 24ms/step - loss: 9.1495 - accuracy: 0.4000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 2/200
# 10/10 [==============================] - 0s 27ms/step - loss: 6.0997 - accuracy: 0.6000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 3/200
# 10/10 [==============================] - 0s 25ms/step - loss: 10.6745 - accuracy: 0.3000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 4/200
# 10/10 [==============================] - 0s 24ms/step - loss: 6.0997 - accuracy: 0.6000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 5/200
# 10/10 [==============================] - 0s 23ms/step - loss: 9.1495 - accuracy: 0.4000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 6/200
# 10/10 [==============================] - 0s 24ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 7/200
# ...

# %%
model.fit_generator(train_set,steps_per_epoch=10,epochs=300 , validation_data = test_set)
# Out:
# Epoch 1/300
# 10/10 [==============================] - 0s 27ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 2/300
# 10/10 [==============================] - 0s 26ms/step - loss: 4.5748 - accuracy: 0.7000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 3/300
# 10/10 [==============================] - 0s 24ms/step - loss: 9.1495 - accuracy: 0.4000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 4/300
# 10/10 [==============================] - 0s 26ms/step - loss: 10.6745 - accuracy: 0.3000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 5/300
# 10/10 [==============================] - 0s 27ms/step - loss: 6.0997 - accuracy: 0.6000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 6/300
# 10/10 [==============================] - 0s 25ms/step - loss: 9.1495 - accuracy: 0.4000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 7/300
# ...

# %%
test_score = model.evaluate(test_set)

print('Test loss {:.4f}, accuracy {:.2f}'.format(test_score[0], test_score[1] * 100))
# Out:
# 20/20 [==============================] - 0s 7ms/step - loss: 7.6246 - accuracy: 0.5000
# Test loss 7.6246, accuracy 50.00
